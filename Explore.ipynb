# %%
from pandas import DataFrame, Series
import pandas as pd

# %%
pd.read_table("data/Town-Hall-Rich-List-2012/Town-Hall-Rich-List-2012.txt")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 412 entries, 0 to 411
# Data columns:
# Council                               412  non-null values
# Name                                  212  non-null values
# Job Title                             412  non-null values
# 2009-10                               412  non-null values
# 2010-11                               412  non-null values
# % Change                              412  non-null values
# Full details for 2010-11 and Notes    407  non-null values
# dtypes: object(7)

# %%
data = _

# %%
data.columns = ["council", "name", "title", "09-10", "10-11", "change", "details"]

# %%
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 412 entries, 0 to 411
# Data columns:
# council    412  non-null values
# name       212  non-null values
# title      412  non-null values
# 09-10      412  non-null values
# 10-11      412  non-null values
# change     412  non-null values
# details    407  non-null values
# dtypes: object(7)

# %%
c_data = data.convert_objects()

# %%
c_data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 412 entries, 0 to 411
# Data columns:
# council    412  non-null values
# name       212  non-null values
# title      412  non-null values
# 09-10      412  non-null values
# 10-11      412  non-null values
# change     412  non-null values
# details    407  non-null values
# dtypes: object(7)

# %%
data['10-11'] = data['10-11'].apply(clean)

# %%
def clean(sn):
    if sn == "-":
        return 0
    else:
        return long(str.replace(sn, ",", ""))

# %%
def clean_pct(sp):
    if sp == "-":
        return np.float64(0.0)
    else:
        return np.float64(str.replace(sp, "%", ""))

# %%
data.change = data.change.apply(clean_pct)

# %%
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 412 entries, 0 to 411
# Data columns:
# council    412  non-null values
# name       212  non-null values
# title      412  non-null values
# 09-10      412  non-null values
# 10-11      412  non-null values
# change     412  non-null values
# details    407  non-null values
# dtypes: float64(1), int64(2), object(4)

# %%
plt.scatter(data['09-10'][(data['09-10'] > 0) & (data['10-11'] > 0)], data['10-11'][(data['09-10'] > 0) & (data['10-11'] > 0)])

# %%
tax_data = pd.read_table("data/Council-tax-Band-D.txt")

# %%
tax_data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 480 entries, 0 to 479
# Data columns:
# Authority     479  non-null values
# 2000-01       479  non-null values
# 2001-02       479  non-null values
# 2002-03       479  non-null values
# 2003-04       479  non-null values
# 2004-05       479  non-null values
# 2005-06       479  non-null values
# 2006-07       479  non-null values
# 2007-08       479  non-null values
# 2008-09       479  non-null values
# 2009-10       479  non-null values
# 2010-11       479  non-null values
# % Increase    479  non-null values
# dtypes: object(13)

# %%
def clean_tax(st):
    st = str(st)
    if st == "-":
        return np.float64(0)
    else:
        return np.float64(str.replace(st,",",""))

# %%
tax_data.columns
# Out:
# Index([Authority, 2000-01, 2001-02, 2002-03, 2003-04, 2004-05, 2005-06, 2006-07, 2007-08, 2008-09, 2009-10, 2010-11, % Increase], dtype=object)

# %%
year_cols = ['2000-01', '2001-02', '2002-03', '2003-04', '2004-05', '2005-06', '2006-07', '2007-08', '2008-09', '2009-10', '2010-11']

# %%
tax_data[year_cols] = tax_data[year_cols].applymap(clean_tax)
# Out:
# /Library/Python/2.7/site-packages/pandas/core/frame.py:3576: FutureWarning: rename with inplace=True  will return None from pandas 0.11 onward
#   " from pandas 0.11 onward", FutureWarning)

# %%
tax_data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 480 entries, 0 to 479
# Data columns:
# Authority     479  non-null values
# 2000-01       479  non-null values
# 2001-02       479  non-null values
# 2002-03       479  non-null values
# 2003-04       479  non-null values
# 2004-05       479  non-null values
# 2005-06       479  non-null values
# 2006-07       479  non-null values
# 2007-08       479  non-null values
# 2008-09       479  non-null values
# 2009-10       479  non-null values
# 2010-11       479  non-null values
# % Increase    479  non-null values
# dtypes: float64(11), object(2)

# %%
tax_data['2000-01']
# Out:
# 0     873.00
# 1     777.00
# 2     163.52
# 3     119.40
# 4     128.27
# 5     771.00
# 6     938.00
# 7     135.07
# 8     125.67
# 9      94.00
# 10    109.43
# 11    129.53
# 12    661.44
# 13    691.91
# 14    757.17
# ...
# 465    911.01
# 466    137.33
# 467    828.19
# 468    913.77
# 469      0.00
# 470    109.41
# 471    611.67
# 472    122.58
# 473    701.15
# 474    111.61
# 475    114.50
# 476    112.13
# 477    145.52
# 478    690.75
# 479       NaN
# Name: 2000-01, Length: 480

# %%
tax_data[year_cols].T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, 2000-01 to 2010-11
# Columns: 480 entries, 0 to 479
# dtypes: float64(480)

# %%
tax_data.to_csv("data/cleaned/tax_data.csv")

# %%
data.to_csv("data/cleaned/pay_data.csv")

# %%
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 412 entries, 0 to 411
# Data columns:
# council    412  non-null values
# name       212  non-null values
# title      412  non-null values
# 09-10      412  non-null values
# 10-11      412  non-null values
# change     412  non-null values
# details    407  non-null values
# dtypes: float64(1), int64(2), object(4)

# %%
tax_data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 480 entries, 0 to 479
# Data columns:
# council       479  non-null values
# 2000-01       479  non-null values
# 2001-02       479  non-null values
# 2002-03       479  non-null values
# 2003-04       479  non-null values
# 2004-05       479  non-null values
# 2005-06       479  non-null values
# 2006-07       479  non-null values
# 2007-08       479  non-null values
# 2008-09       479  non-null values
# 2009-10       479  non-null values
# 2010-11       479  non-null values
# % Increase    479  non-null values
# dtypes: float64(11), object(2)

# %%
column_names = list(tax_data.columns)

# %%
column_names[0] = 'council'

# %%
tax_data.columns = column_names

# %%
all_data = pd.merge(tax_data, data)

# %%
all_data.to_csv("data/cleaned/combined_data.csv")

# %%
all_data['2010-11'].corr(all_data['10-11'])
# Out:
# 0.30269717508350102

# %%
all_data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 378 entries, 0 to 377
# Data columns:
# council       378  non-null values
# 2000-01       378  non-null values
# 2001-02       378  non-null values
# 2002-03       378  non-null values
# 2003-04       378  non-null values
# 2004-05       378  non-null values
# 2005-06       378  non-null values
# 2006-07       378  non-null values
# 2007-08       378  non-null values
# 2008-09       378  non-null values
# 2009-10       378  non-null values
# 2010-11       378  non-null values
# % Increase    378  non-null values
# name          194  non-null values
# title         378  non-null values
# 09-10         378  non-null values
# 10-11         378  non-null values
# change        378  non-null values
# details       373  non-null values
# dtypes: float64(12), int64(2), object(5)

# %%
hack_data = all_data[['council','2010-11','10-11','details','name','title']].copy()

# %%
hack_data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 378 entries, 0 to 377
# Data columns:
# council    378  non-null values
# 2010-11    378  non-null values
# 10-11      378  non-null values
# details    373  non-null values
# name       194  non-null values
# title      378  non-null values
# dtypes: float64(1), int64(1), object(4)

# %%
hack_data.columns = ['Council','TaxRate','Pay','Details','Name','Title']

# %%
hack_data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 378 entries, 0 to 377
# Data columns:
# Council    378  non-null values
# TaxRate    378  non-null values
# Pay        378  non-null values
# Details    373  non-null values
# Name       194  non-null values
# Title      378  non-null values
# dtypes: float64(1), int64(1), object(4)

# %%
import json

# %%
lol = []
for name in ['Council','TaxRate','Pay','Details','Name','Title']:
    lol.append(list(hack_data[name]))

# %%
items = []
for index in range(len(lol[0])):
    item = {}
    item['Council'] = lol[0][index]
    item['TaxRate'] = lol[1][index]
    item['Pay'] = lol[2][index]
    item['Details'] = str.replace(lol[3][index], "\xa3", "")
    item['Name'] = lol[4][index]
    item['Title'] = lol[5][index]
    items.append(item)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-136-2bce002b8242> in <module>()
#       5     item['TaxRate'] = lol[1][index]
#       6     item['Pay'] = lol[2][index]
# ----> 7     item['Details'] = str.replace(lol[3][index], "\xa3", "")
#       8     item['Name'] = lol[4][index]
#       9     item['Title'] = lol[5][index]
#
# TypeError: descriptor 'replace' requires a 'str' object but received a 'float'

# %%
items
# Out:
# [{'Council': 'Aberdeen City',
#   'Details': 'Salary, fees & allowances \xa3107,272; Compensation for loss of employment \xa31909; Pension contribution \xa320,517. The value of compensation for loss of employment is in relation to pay in lieu of holidays. Left 31 December 2010',
#   'Name': 'Sue Bruce',
#   'Pay': 129698,
#   'TaxRate': 1230.0,
#   'Title': 'Chief Executive '},
#  {'Council': 'Aberdeenshire',
#   'Details': 'Gross salary, fees & allowances \xa3143,121; Pension contributions \xa327,479',
#   'Name': 'Colin Mackenzie',
#   'Pay': 170600,
#   'TaxRate': 1141.0,
#   'Title': 'Chief Executive'},
#  {'Council': 'Adur',
#   'Details': 'Salary incl fees & allowances \xa3115,510; Expense allowance \xa398; Benefit in kind \xa31,433; Pension contribution \xa318,713. This post is shared with Worthing BC, they contributed \xa367,828 towards the cost',
#   'Name': nan,
#   'Pay': 135656,
#   'TaxRate': 286.94,
#   'Title': 'Chief Executive (Shared with Worthing BC)'},
# ...

# %%
f = open("data/hack_data.json", "w")

# %%
all_data.columns
# Out:
# Index([council, 2000-01, 2001-02, 2002-03, 2003-04, 2004-05, 2005-06, 2006-07, 2007-08, 2008-09, 2009-10, 2010-11, % Increase, name, title, 09-10, 10-11, change, details], dtype=object)

# %%
pop_data = pd.read_table("data/Population.txt")

# %%
pop_data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 462 entries, 0 to 461
# Data columns:
# ORDER                                                            457  non-null values
# Area                                                             459  non-null values
# Local authority                                                  457  non-null values
# ONS Code                                                         406  non-null values
# Mid- 1999 population                                             457  non-null values
# Mid-2008 population                                              457  non-null values
# Components of change 2008-2009: Live births                      457  non-null values
# Components of change 2008-2009: Deaths                           457  non-null values
# Components of change 2008-2009: Natural change                   457  non-null values
# Components of change 2008-2009: Net migration & other changes    457  non-null values
# ...

# %%
a_names = list(pop_data["Local authority"])len(set(a_names) & set(c_names))

# %%
c_names = list(hack_data.Council)

# %%
len(set(a_names) & set(c_names))
# Out:
# 295

# %%
pop_data['Mid-2009 population']
# Out:
# 0     61,792.0
# 1     60,003.1
# 2     54,809.1
# 3     51,809.7
# 4      2,584.3
# 5        506.4
# 6        100.4
# 7         90.9
# 8        140.5
# 9        311.1
# 10       137.5
# 11       191.1
# 12     1,106.3
# 13       190.8
# 14       284.3
# ...
# 447     31.4
# 448     34.0
# 449    116.5
# 450     44.2
# 451     16.9
# 452     98.7
# 453     83.4
# 454     79.6
# 455     52.4
# 456     39.9
# 457      NaN
# 458      NaN
# 459      NaN
# 460      NaN
# 461      NaN
# Name: Mid-2009 population, Length: 462

# %%
pop_data['Local authority'].apply(lambda s: str.replace(str(s), " UA", ""))
# Out:
# 0                             UK
# 1                  GREAT BRITAIN
# 2                ENGLAND & WALES
# 3                        ENGLAND
# 4                     NORTH EAST
# 5                  County Durham
# 6                     Darlington
# 7                     Hartlepool
# 8                  Middlesbrough
# 9                 Northumberland
# 10          Redcar and Cleveland
# 11              Stockton-on-Tees
# 12    Tyne and Wear (Met County)
# 13                     Gateshead
# 14           Newcastle upon Tyne
# ...
# 447             Larne
# 448          Limavady
# 449           Lisburn
# 450       Magherafelt
# 451             Moyle
# 452    Newry & Mourne
# 453      Newtownabbey
# 454        North Down
# 455             Omagh
# 456          Strabane
# 457               nan
# 458               nan
# 459               nan
# 460               nan
# 461               nan
# Name: Local authority, Length: 462

# %%
pop_data['Local authority'] = pop_data['Local authority'].apply(lambda s: str.replace(str(s), " UA", ""))

# %%
pop_data['Local authority']
# Out:
# 0                             UK
# 1                  GREAT BRITAIN
# 2                ENGLAND & WALES
# 3                        ENGLAND
# 4                     NORTH EAST
# 5                  County Durham
# 6                     Darlington
# 7                     Hartlepool
# 8                  Middlesbrough
# 9                 Northumberland
# 10          Redcar and Cleveland
# 11              Stockton-on-Tees
# 12    Tyne and Wear (Met County)
# 13                     Gateshead
# 14           Newcastle upon Tyne
# ...
# 447             Larne
# 448          Limavady
# 449           Lisburn
# 450       Magherafelt
# 451             Moyle
# 452    Newry & Mourne
# 453      Newtownabbey
# 454        North Down
# 455             Omagh
# 456          Strabane
# 457               nan
# 458               nan
# 459               nan
# 460               nan
# 461               nan
# Name: Local authority, Length: 462

# %%
len(set(a_names) & set(c_names))
# Out:
# 295

# %%
pop_data.columns
# Out:
# Index([ORDER, Area, Local authority, ONS Code, Mid- 1999 population, Mid-2008 population, Components of change 2008-2009: Live births, Components of change 2008-2009: Deaths, Components of change 2008-2009: Natural change, Components of change 2008-2009: Net migration & other changes, Total change, 2008-2009, Mid-2009 population, % change 2008-2009, % change 1999 to 2009], dtype=object)

# %%
pop_df = pop_data[['Local authority','Mid-2009 population']].copy()

# %%
pop_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 462 entries, 0 to 461
# Data columns:
# Local authority        462  non-null values
# Mid-2009 population    457  non-null values
# dtypes: object(2)

# %%
pop_df.columns = ["council", "population"]

# %%
pop_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 462 entries, 0 to 461
# Data columns:
# council       462  non-null values
# population    457  non-null values
# dtypes: object(2)

# %%
combined_data = pd.merge(all_data, pop_df)

# %%
combined_data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 370 entries, 0 to 369
# Data columns:
# council       370  non-null values
# 2000-01       370  non-null values
# 2001-02       370  non-null values
# 2002-03       370  non-null values
# 2003-04       370  non-null values
# 2004-05       370  non-null values
# 2005-06       370  non-null values
# 2006-07       370  non-null values
# 2007-08       370  non-null values
# 2008-09       370  non-null values
# 2009-10       370  non-null values
# 2010-11       370  non-null values
# % Increase    370  non-null values
# name          188  non-null values
# title         370  non-null values
# 09-10         370  non-null values
# 10-11         370  non-null values
# change        370  non-null values
# details       365  non-null values
# population    370  non-null values
# dtypes: float64(12), int64(2), object(6)

# %%
# %history
# Out:
# from pandas import DataFrame, Series
# import pandas.io.parsers.ExcelFile as xlf
# import pandas.io.parsers as parsers
# data = parsers.ExcelFile.parse("data/Town-Hall-Rich-List-2012/Town-Hall-Rich-List-2012.xlsx", "Chief Executive")
# xls = parsers.ExcelFile()
# xls = parsers.ExcelFile("data/Town-Hall-Rich-List-2012/Town-Hall-Rich-List-2012.xlsx")
# xls.parse("Chief Executive")
# data = _
# data
# data.plot()
# from pandas import DataFrame, Series
# import pandas as pd
# pd.read_csv("data/Town-Hall-Rich-List-2012/Town-Hall-Rich-List-2012.csv")
# pd.read_csv("data/Town-Hall-Rich-List-2012/Town-Hall-Rich-List-2012.csv")
# pd.read_csv("data/Town-Hall-Rich-List-2012/Town-Hall-Rich-List-2012.csv")
# pd.read_table("data/Town-Hall-Rich-List-2012/Town-Hall-Rich-List-2012.txt")
# data = _
# data.plot()
# data.columns = ["council", "name", "title", "09-10", "10-11", "pct_change", "details"]
# data
# data.pct_change.plot()
# data.pct_change
# data['pct_change'].plot()
# data['09-10'].plot()
# ...

# %%
hack_data = combined_data[['council','2010-11','10-11','details','name','title','population']].copy()
hack_data.columns = ['Council','TaxRate','Pay','Details','Name','Title','Population']

lol = []
for name in ['Council','TaxRate','Pay','Details','Name','Title','Population']:
    lol.append(list(hack_data[name]))

items = []
for index in range(len(lol[0])):
    item = {}
    item['Council'] = lol[0][index]
    item['TaxRate'] = lol[1][index]
    item['Pay'] = lol[2][index]
    item['Details'] = lol[3][index]
    item['Name'] = lol[4][index]
    item['Title'] = lol[5][index]
    item['Population'] = lol[6][index]
    items.append(item)

# %%
json.dumps(items)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-166-bb8a0714e034> in <module>()
# ----> 1 json.dumps(items)
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, encoding, default, **kw)
#     229         cls is None and indent is None and separators is None and
#     230         encoding == 'utf-8' and default is None and not kw):
# --> 231         return _default_encoder.encode(obj)
#     232     if cls is None:
#     233         cls = JSONEncoder
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py in encode(self, o)
#     199         # exceptions aren't as detailed.  The list call should be roughly
#     200         # equivalent to the PySequence_Fast that ''.join() would do.
# ...
